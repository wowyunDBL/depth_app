# %%
import sys
if sys.platform.startswith('linux'): # or win
    print("in linux")
    file_path = "/home/anny/109-2/0420_treeExperiment/npy/"
#     sys.path.remove('/opt/ros/kinetic/lib/python2.7/dist-packages')
else:
    file_path = r"G:/我的雲端硬碟/0327_align_depth/"
# Out:
# in linux

# %%
'''math tool'''
import csv
import numpy as np

'''plot tool'''
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import matplotlib.ticker as ticker

'''image tool'''
import cv2
import pyrealsense2 as rs
import statistics as sta

# %%
npDepth = []

npDepth = np.load(file_path+"21.npy")

npDepthF = cv2.convertScaleAbs(npDepth, alpha=0.085) # 3m
npDepthF_color = cv2.applyColorMap(npDepthF, cv2.COLORMAP_JET)
# %matplotlib inline
plt.imshow(cv2.cvtColor(npDepthF_color, cv2.COLOR_BGR2RGB))

# %%
color_seq = {'brown': (0,130,210), 'red':(0,0,255),'yellow':(22,220,220),'green':(0,255,0),'blue':(255,0,0),'black':(0,0,0)}
npDepth_seg = np.zeros((npDepth.shape[0],npDepth.shape[1],3))

npDepth_seg[npDepth<1500]=color_seq['blue']
npDepth_seg[np.logical_and(npDepth<2000,npDepth>1500)]=color_seq['green']
npDepth_seg[np.logical_and(npDepth<3000,npDepth>2000)]=color_seq['yellow']
npDepth_seg[np.logical_and(npDepth<6000,npDepth>3000)]=color_seq['red']
npDepth_seg[npDepth>6000]=color_seq['brown']
npDepth_seg[npDepth==0]=color_seq['black']

npDepth_seg = npDepth_seg.astype('uint8')
# %matplotlib inline
plt.imshow(cv2.cvtColor(npDepth_seg, cv2.COLOR_BGR2RGB))

# %%
def depth(x,y):
    return npDepth[x][y]
# class Point3D:
#     x: int = 0
#     y: int = 0
#     z: int = 0
cx_d = 328 #424
cy_d = 241 #241
fx_d = 617 #424
fy_d = 617 #424

npPointX = np.asarray(range(640))-cx_d
npPointX = np.diag(npPointX)
npPointX = npDepth.dot(npPointX)/ fx_d * (-1)
npPointX = npPointX.astype('float16')

npPointY = np.asarray(range(480))-cy_d
npPointY = np.diag(npPointY)
theta = 0/180*np.pi
npPointY = npPointY.dot(npDepth)/ fy_d * (-1) 
npPointY = npPointY*np.cos(theta) + npDepth * np.sin(theta) + 360

npPointY = npPointY.astype('float16')
npPointZ = np.copy(npDepth)

# %%
'''depth segmentation'''
npHeight = np.copy(npPointY)
color_seq = {'brown': (0,130,210), 'red':(0,0,255),'yellow':(22,220,220),
                'green':(0,255,0),'blue':(255,0,0),'black':(0,0,0)}
npHeight_seg = np.zeros((npDepth.shape[0],npDepth.shape[1],3))

npHeight_seg[npHeight<-160]=color_seq['blue']
npHeight_seg[np.logical_and(npHeight<-80,npHeight>-160)]=color_seq['green']
npHeight_seg[np.logical_and(npHeight<0,npHeight>-80)]=color_seq['yellow']
npHeight_seg[np.logical_and(npHeight<80,npHeight>0)]=color_seq['red']
npHeight_seg[npHeight>80]=color_seq['brown']
npHeight_seg[npHeight==360]=color_seq['black']
npHeight_seg[np.logical_and(npHeight<0.9,npHeight>-0.9)]=(255,255,255)
# print(*(npDepth[np.logical_and(npHeight<0.9,npHeight>-0.9)]))
print(npHeight.dtype)
npHeight_seg = npHeight_seg.astype('uint8')
# %matplotlib inline
plt.imshow(cv2.cvtColor(npHeight_seg, cv2.COLOR_BGR2RGB))
# Out:
# float16

# %%
print(npPointX.shape)
print(npPointY.shape)
print(npPointZ.shape)
npPointXYZ = np.vstack((npPointX[300],npPointY[300],npPointZ[300]))
print(npPointXYZ.shape)
temp1 = npPointXYZ[:,npPointXYZ[1,:]<-120]
temp1.reshape(3,-1)
temp4 = npPointXYZ[:,npPointXYZ[1,:]>-120]
temp4.reshape(3,-1)
print(temp1.shape)
# Out:
# (480, 640)
# (480, 640)
# (480, 640)
# (3, 640)
# (3, 475)

# %%
npPointXYZ = np.vstack((npPointX[380],npPointY[380],npPointZ[380]))
temp2 = npPointXYZ[:,npPointXYZ[1,:]<-120]
temp2.reshape(3,-1)
# Out:
# (3, 640)
# array([[ 1257.,  1253.,  1250., ..., -2200., -2206., -2212.],
#        [ -172.,  -172.,  -172., ...,  -629.,  -629.,  -629.],
#        [ 2364.,  2364.,  2364., ...,  4391.,  4391.,  4391.]],
#       dtype=float32)

# %%
npPointXYZ = np.vstack((npPointX[340],npPointY[340],npPointZ[340]))
temp3 = npPointXYZ[:,npPointXYZ[1,:]<-120]
temp3.reshape(3,-1)
# Out:
# array([[ 1969.,  1963.,  1969., ..., -5496., -5516., -5532.],
#        [ -234.,  -234.,  -237., ..., -1401., -1401., -1401.],
#        [ 3703.,  3703.,  3726., ..., 10977., 10977., 10977.]],
#       dtype=float32)

# %%
npPointXYZ = np.vstack((npPointX[400],npPointY[400],npPointZ[400]))
temp4 = npPointXYZ[:,npPointXYZ[1,:]<-120]
temp4.reshape(3,-1)
# Out:
# array([[ 1072.,  1068.,  1069., ..., -1489., -1494., -1499.],
#        [ -159.,  -159.,  -161., ...,  -408.,  -408.,  -408.],
#        [ 2015.,  2015.,  2022., ...,  2984.,  2984.,  2984.]],
#       dtype=float32)

# %%
npPointXYZ = np.vstack((npPointX[360],npPointY[360],npPointZ[360]))
temp5 = npPointXYZ[:,npPointXYZ[1,:]<-120]
temp5.reshape(3,-1)
# Out:
# array([[ 1500.,  1495.,  1497., ..., -3372., -3382., -3392.],
#        [ -183.,  -183.,  -186., ...,  -942.,  -942.,  -942.],
#        [ 2820.,  2820.,  2833., ...,  6755.,  6755.,  6755.]],
#       dtype=float32)

# %%
npPointXYZ = np.vstack((npPointX[370],npPointY[370],npPointZ[370]))
temp6 = npPointXYZ[:,npPointXYZ[1,:]<-120]
temp6.reshape(3,-1)
# Out:
# array([[ 1374.,  1375.,  1371., ..., -2676., -2684., -2694.],
#        [ -180.,  -182.,  -182., ...,  -757.,  -757.,  -757.],
#        [ 2583.,  2594.,  2594., ...,  5345.,  5345.,  5345.]],
#       dtype=float32)

# %%
fig, ax = plt.subplots(figsize=(5, 5), dpi=100)
plt.grid(True)
plt.scatter(0, 0, c='r', s=200, marker='*')
plt.scatter(temp1[0]/1000,temp1[2]/1000,c='g', s=10)
plt.scatter(temp2[0]/1000,temp2[2]/1000,c='yellow', s=10)
plt.scatter(temp3[0]/1000,temp3[2]/1000,c='blue', s=10)
plt.scatter(temp4[0]/1000,temp4[2]/1000,c='r', s=10)
plt.scatter(temp5[0]/1000,temp5[2]/1000,c='orange', s=10)
plt.scatter(temp6[0]/1000,temp6[2]/1000,c='black', s=10)
plt.show()

# %%
ret, npHeight_binary = cv2.threshold(npHeight, -100, 255, cv2.THRESH_BINARY) # below 100mm
npHeight_binary = npHeight_binary.astype('uint8')
plt.imshow(cv2.cvtColor(npHeight_binary, cv2.COLOR_GRAY2RGB))

# %%
test = np.zeros((480,640), dtype=np.int32)
test[:240]=6000
test[240:480]=-30-360

cx_d = 328 #424
cy_d = 241 #241
fx_d = 617 #424
fy_d = 617 #424

npPointY = np.asarray(range(480))-cy_d
npPointY[npPointY==0]=1
print(npPointY[479])
npPointY = -float(1)/npPointY
print(npPointY[479])
npPointY = np.diag(npPointY)

print(npPointY[479][479])
print(test[479][0])
test = test*fy_d
test = npPointY.dot(test)
print(test[479][0])

'''depth segmentation'''
npDepth = np.copy(test)
color_seq = {'brown': (0,130,210), 'red':(0,0,255),'yellow':(22,220,220),
                'green':(0,255,0),'blue':(255,0,0),'black':(0,0,0)}
npDepth_seg = np.zeros((npDepth.shape[0],npDepth.shape[1],3))

npDepth_seg[npDepth<1500]=color_seq['blue']
npDepth_seg[np.logical_and(npDepth<2000,npDepth>1500)]=color_seq['green']
npDepth_seg[np.logical_and(npDepth<3000,npDepth>2000)]=color_seq['yellow']
npDepth_seg[np.logical_and(npDepth<6000,npDepth>3000)]=color_seq['red']
npDepth_seg[npDepth>6000]=color_seq['brown']
npDepth_seg[npDepth==0]=color_seq['black']

npDepth_seg = npDepth_seg.astype('uint8')
# %matplotlib inline
plt.imshow(cv2.cvtColor(npDepth_seg, cv2.COLOR_BGR2RGB))
# Out:
# 238
# -0.004201680672268907
# -0.004201680672268907
# -390
# 1011.0504201680671

# %%
npDepth_test = np.copy(npDepth)

npPointY = np.asarray(range(480))-cy_d
npPointY = np.diag(npPointY)
theta = -float(4.5)/180*np.pi
print(theta)
npPointY = npPointY.dot(npDepth)/ float(fy_d) * float(-1) 
npPointY = npPointY*np.cos(theta) + 360 + npDepth * np.sin(theta)

npPointY = npPointY.astype('float16')

'''depth segmentation'''
npHeight = np.copy(npPointY)
color_seq = {'brown': (0,130,210), 'red':(0,0,255),'yellow':(22,220,220),
                'green':(0,255,0),'blue':(255,0,0),'black':(0,0,0)}
npHeight_seg = np.zeros((npDepth.shape[0],npDepth.shape[1],3))

npHeight_seg[npHeight<-160]=color_seq['blue']
npHeight_seg[np.logical_and(npHeight<-80,npHeight>-160)]=color_seq['green']
npHeight_seg[np.logical_and(npHeight<0,npHeight>-80)]=color_seq['yellow']
npHeight_seg[np.logical_and(npHeight<80,npHeight>0)]=color_seq['red']
npHeight_seg[npHeight>80]=color_seq['brown']
npHeight_seg[npHeight==360]=color_seq['black']
npHeight_seg[np.logical_and(npHeight<0.9,npHeight>-0.9)]=(255,255,255)
# print(*(npDepth[np.logical_and(npHeight<0.9,npHeight>-0.9)]))
print(npHeight.dtype)
npHeight_seg = npHeight_seg.astype('uint8')
# %matplotlib inline
plt.imshow(cv2.cvtColor(npHeight_seg, cv2.COLOR_BGR2RGB))
# Out:
# -0.0785398163397
# float16
